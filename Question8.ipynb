# %%
students_records = {
    2022: {
        'Branch 1': {
            1: {'Name': 'Adi', 'Marks': {'Maths': 100, 'English': 70}},
            2: {'Name': 'Ben', 'Marks': {'Maths': 95, 'English': 80}},
        },
        'Branch 2': {
            1: {'Name': 'Shreyas', 'Marks': {'Maths': 100, 'English': 87}},
            2: {'Name': 'Shreya', 'Marks': {'Maths': 85, 'English': 75}},
        },
    },
    2023: {
        'Branch 1': {
            1: {'Name': 'Aditya', 'Marks': {'Maths': 88, 'English': 78}},
            2: {'Name': 'Kanika', 'Marks': {'Maths': 92, 'English': 82}},
        },
        'Branch 2': {
            1: {'Name': 'Rahul', 'Marks': {'Maths': 89, 'English': 79}},
            2: {'Name': 'Hitesh', 'Marks': {'Maths': 94, 'English': 84}},
        },
    },
    2024: {
        'Branch 1': {
            1: {'Name': 'Tanmay', 'Marks': {'Maths': 85, 'English': 80}},
            2: {'Name': 'Shreyas', 'Marks': {'Maths': 87, 'English': 77}},
        },
        'Branch 2': {
            1: {'Name': 'Manit', 'Marks': {'Maths': 90, 'English': 85}},
            2: {'Name': 'Niraj', 'Marks': {'Maths': 100, 'English': 81}},
        },
    },
    2025: {
        'Branch 1': {
            1: {'Name': 'Shreya', 'Marks': {'Maths': 93, 'English': 83}},
            2: {'Name': 'Pritish', 'Marks': {'Maths': 88, 'English': 78}},
        },
        'Branch 2': {
            1: {'Name': 'Sid', 'Marks': {'Maths': 92, 'English': 82}},
            2: {'Name': 'Terry', 'Marks': {'Maths': 89, 'English': 91}},
        },
    },
}

# %% [markdown]
# Now we will create the database using the student records as shown above in the dictionary.

# %%
class Student:
    def __init__(self, roll_number, name, marks):
        self.roll_number = roll_number
        self.name = name
        self.marks = marks

    def __repr__(self):
        return f"Student(Roll Number: {self.roll_number}, Name: {self.name}, Marks: {self.marks})"


class Branch:
    def __init__(self, name):
        self.name = name
        self.students = []

    def add_student(self, student):
        self.students.append(student)

    def __repr__(self):
        return f"Branch(Name: {self.name}, Students: {self.students})"


class Year:
    def __init__(self, year):
        self.year = year
        self.branches = []

    def add_branch(self, branch):
        self.branches.append(branch)

    def __repr__(self):
        return f"Year({self.year}, Branches: {self.branches})"


class Database:
    def __init__(self):
        self.years = []

    def add_year(self, year):
        self.years.append(year)

    def __repr__(self):
        return f"Database(Years: {self.years})"


# Create the database
db = Database()

# Add data for each year
for year, branches in students_records.items():
    year_obj = Year(year)
    for branch_name, students in branches.items():
        branch_obj = Branch(branch_name)
        for roll_number, student_info in students.items():
            student_obj = Student(roll_number, student_info['Name'], student_info['Marks'])
            branch_obj.add_student(student_obj)
        year_obj.add_branch(branch_obj)
    db.add_year(year_obj)
